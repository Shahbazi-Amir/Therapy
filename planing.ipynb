# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# حتماً امیر 🌿
# بریم دقیق و تمیز — هم جدول روزانهٔ نهایی (نسخه‌ی تأییدشده‌ات)
# و هم مجموعه‌ی کامل «مشکلات شروع کار و راه‌حل‌های واقعی» که باهاش هماهنگه.
#
# ---
#
# # 🕰️ برنامهٔ روزانهٔ نهایی امیر
#
# | شماره |     ساعت    | عنوان / بخش                        | توضیحات                                         |
# | :---: | :---------: | :--------------------------------- | :---------------------------------------------- |
# |   1   | 04:30–05:00 | بیداری + سحری + وضو + کشش          | شروع روز و بیدارسازی ذهن                        |
# |   2   | 05:00–05:30 | نماز صبح                           |                                                 |
# |   3   | 05:30–07:30 | زیارت / حرم                        | بدون گوشی، تمرکز درونی                          |
# |   4   | 07:30–08:00 | زبان در خانه + کشش                 | در روز غیرروزه = صبحانه هم                      |
# |   5   | 08:00–08:30 | مسیر تا محل کار                    | نیم‌ساعت انتقال ذهنی                            |
# |   6   | 08:30–11:30 | بلوک A – ۴ پومو (۳۵/۷)             | کدنویسی سنگین پایتون / پشتیبان یادگیری          |
# |   7   | 11:30–12:30 | قیلوله + نماز ظهر                  | خواب ۲۰ دقیقه + وضو و نماز                      |
# |   8   | 12:30–15:30 | بلوک B – ۴ پومو (۳۵/۷)             | یادگیری ماشین سنگین، مدل‌سازی و آزمون           |
# |   9   | 15:30–16:00 | قدم‌زدن عصر + آب                   | استراحت بدنی، ذهنی و عبادی                      |
# |   10  | 16:00–17:17 | اسلات C1 – ۲ پومو (۳۵/۷)           | ارشد (مطالعه یا تست‌زنی)                        |
# |   11  | 17:17–17:43 | افطار + نماز مغرب                  | روزه‌گشایی و عبادت                              |
# |   12  | 17:43–19:00 | اسلات C2 – ۲ پومو (۳۵/۷)           | ارشد یا جمع‌بندی نهایی                          |
# |   13  | 19:00–19:30 | مسیر برگشت                         |                                                 |
# |   14  | 19:30–20:00 | دوش و آرام‌سازی                    | آماده‌سازی ذهن برای عصر                         |
# |   15  | 20:00–22:00 | شام + سیت‌کام انگلیسی              | تفریح سبک + زبان شب (۳۰–۴۵ دقیقه)               |
# |   16  | 22:00–23:00 | مطالعه سبک / مرور + یادداشت سه‌خطی | بستن روز و نیت فردا                             |
# |   17  |    23:00    | خواب شب                            | اگر خواب تنظیم نباشد، هیچ برنامه‌ای پایدار نیست |
#
# ---
#
# # ⚙️ مشکلات رایج شروع کار و کدنویسی + راه‌حل‌ها
#
# | مشکل                                                     | توضیح دقیق                                                  | راه‌حل عملی                                                                                                           |
# | -------------------------------------------------------- | ----------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------- |
# | **۱. ذهن می‌فهمد «فریب ۵ دقیقه‌ای» است و مقاومت می‌کند** | مغز یاد گرفته که “فقط ۵ دقیقه” یعنی فریب برای شروع کار سخت. | به‌جای «۵ دقیقه کار»، فقط **محیط پروژه را باز کن** (VSCode، فولدر، نوت دیروز). به این می‌گن *Not-Working Microstart*. |
# | **۲. شروع از نقطهٔ گره‌خورده دیروز**                     | کار ناتمام یا با خطا رها شده و ذهن آن را تهدید می‌بیند.     | در پایان روز قبل بنویس: “اینجا گیر کردم، قدم بعدی فردا این است…”؛ صبح فقط همان قدم را اجرا کن.                        |
# | **۳. کار نیمه‌تمام ذهن را مشغول نگه می‌دارد**            | مغز به خاطر *اثر Zeigarnik* مدام درگیر ناتمامی است.         | عمداً یک خط کد یا جملهٔ ناتمام بگذار تا فردا “ادامه دهی” نه “شروع”.                                                   |
# | **۴. اضطراب تصمیم صبحگاهی**                              | صبح باید از صفر تصمیم بگیری چه کنی.                         | شب قبل فقط سه خط بنویس: «چی ساختم، مانع چی بود، فردا از چی شروع کنم.» (یادداشت سه‌خطی).                               |
# | **۵. گیر در مقاومت بدنی و ذهنی**                         | ذهن می‌داند کار سخت است، بدن را عقب می‌کشد.                 | وضو بگیر + سه نفس عمیق ۴–۴–۴ بکش + بنویس: «نیت من نظم و برکت است.» سپس فقط فایل را باز کن.                            |
# | **۶. نداشتن Warm-up شناختی**                             | ذهن باید از حالت استراحت به حالت حل‌مسئله برود.             | قبل از پومو اول، ۵ دقیقه فایل قبلی را مرور کن یا کد را بخوان بدون تغییر.                                              |
# | **۷. فرار ذهنی (موبایل / وب)**                           | مغز دنبال پاداش سریع می‌گردد.                               | قانون “در نیمه‌باز ممنوع”: اگر گیر کردی، فقط روی میز بمان؛ کاری نکن، ولی نرو سراغ گوشی.                               |
# | **۸. خستگی یا دل‌زدگی از پروژه**                         | انرژی عصبی افت کرده.                                        | بلوک بعدی را کوتاه کن (۲ پومو به‌جای ۴) یا تمرکز را روی تسک کوچک بگذار.                                               |
# | **۹. بی‌نظمی خواب**                                      | ریتم تمرکز از بین می‌رود.                                   | خواب منظم‌تر از هر تکنیک دیگر بهره‌وری را بالا می‌برد؛ تنظیم خواب شرط برکت کار است.                                   |
# | **۱۰. حس سردی عصرها / شب‌ها**                            | افت قند + خستگی شناختی                                      | یک قدم‌زدن، آب سرد به صورت، و نیت “برای رضای خدا و نظم عقل” ذهن را باز می‌کند.                                        |
#
# ---
#
# # ✏️ یادداشت سه‌خطی (شب‌ها)
#
# > 🎯 امروز چه ساختم؟
# > 🚧 چه مانعی داشتم؟
# > 🔁 اولین کار فردا چیه؟
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# امروز دوشنبه ۱۷ آذر ۱۴۰۴
# در قسمت کد که برای لیت کد بود قسمت ۵ حل شد اما خودم کدنویسی نکردم
# در قسمت یادگیری ماشین کوين محلی اجرا شد.
# در قسمت ارشد ثبت نام ارشد ۱۴۰۵
#
#
#
#
#
#
# مانع کدنویسی هم خود هوش مصنوعی هم عدم کدنویسی خودم چون زمانبر است.
# در یادگیری ماشین باز هم مانع هوش مصنوعی و حلقه تکرار و راه بعد مشخص نیست
# ارشد هنوز شروع نشده خواندن وقت نمیشود
#
#
# کار فردا
# گیر کردن در کدنویسی حتی چند خط
# پیدا کردن راه ادامه یادگیری ماشین در سرور یا هر چی
# شروع ارشد
# </div>
