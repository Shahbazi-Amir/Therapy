# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# امروز دوشنبه ۱۷ آذر ۱۴۰۴
# در قسمت کد که برای لیت کد بود قسمت ۵ حل شد اما خودم کدنویسی نکردم
# در قسمت یادگیری ماشین کوين محلی اجرا شد.
# در قسمت ارشد ثبت نام ارشد ۱۴۰۵
#
#
#
#
#
#
# مانع کدنویسی هم خود هوش مصنوعی هم عدم کدنویسی خودم چون زمانبر است.
# در یادگیری ماشین باز هم مانع هوش مصنوعی و حلقه تکرار و راه بعد مشخص نیست
# ارشد هنوز شروع نشده خواندن وقت نمیشود
#
#
# کار فردا
# گیر کردن در کدنویسی حتی چند خط
# پیدا کردن راه ادامه یادگیری ماشین در سرور یا هر چی
# شروع ارشد
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# چهارشنبه ۱۹ آذر ۱۴۰۴
#
# کد:
# سوال ۷ حل شد درباره برگشت اینت در پوشته ۳۲ بیتی
# مانعی وجود نداشت
# فردا سوال هشت
#
# یادگیری ماشین :
# برای راگ به این نتیجه عرسیدم سیستم محلی لپ تاپ ۱۰۰۰ دلاری میخواهد اگر امنیت مهم است.تازه ۵۰ ساعت هم وقت گذاشتم والسلام
# این مانع و نتیجه بود
# اما برای فردا
# اپ ورک فول با همه چی بررسی همه چی و افتادن در آن
# هم زمانش شده
# هم پروژه ها دیده میشود
# هم مالی
# هم بررسی واقعی
# هم سرور میشود استفاده چند کاره کرد
#
#
#
# ارشد:
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# شنبه ۲۲ آذر ۱۴۰۴
# کد:
# سوال ۸ و سوال ۹ حل شد.
# مانع اینکه کدکامل بیاید یادگیری معنا ندارد با هوش مصنوعی هماهنگ شد که جواب ها داده نشود وبا مسیر فکری برویم
# برای فردا سوال ۱۰ ان شاالله
#
#
# یادگیری ماشین وفری لنسرینگ:
# خرید سرور استفتا درباره فریلنسری
# مانع : عدم خرید هلند بخاطر تکمیل ظرفیت و مشکلات ایرنیک
# فردا: کلا بررسی و ادامه با یک سرور و اکانت جدید یا فقط سرچ
#
# ارشد:
# الحمدلله شروع شد ۳ تست حل شد یک ساعت
# مانع های ادیتوری و گیت بود برطرف شد
# فردا ان شاالله بتوانم روزی ده تا تست
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# یکشنبه ۲۳ آذر ماه ۱۴۰۴
#
# کد :
# سوال ده درباره ریجکس کامل حل نشد
# مشکل فهم الگوریتم ها یبازگشتی
# فردا تلاش بیشتر و حل با هر سه الگو
#
#
# فریلنسرینگ :
# سرور سه روز خریداری ولت اوکی اپ ورک هم اوکی
# مانعی نبود
# فردا ان شالله بررسی و درست کردن پروفایل
#
#
#
# ارشد:
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# دوشنبه ۲۴ آذر ماه ۱۴۰۴
# کد:
# سوال ده تمام نشد ولی همه کد خودم
# مانع در تطبیق و جستجوی کاراکتر مانده
# فردا تطبیق و تمام
#
# فریلنسینگ:
# پروژه ها جدید بررسی شد هنوز وقتی پیشنهاد نیست تصمیم به انجام کامل راگ
# مانع عدم عمق در قسمت یادگیری ماشین
# انجام برنچ جدید راگ نهایی
#
#
# ارشد:
# تست ۴ ماند
# مانع ایرادات اساسی چت جی پیتی
# تست ۴
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# سه شنبه را تعطیل نمودم و ضرر هم کردم .
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# چهارشنبه ۲۶ آذر ماه ۱۴۰۴
# کد :
# در ۱۰ مشکل خواندن توکن قبل ستاره حل
# مانع جدید مشکل به ترتیب خواندن و خوردن زودتر ستاره و مانع خالی بودن کارکتر
# فردا حل دو مانع و یک مانع ساده تر
#
#
# پرتاپ آزاد :
# ساختن فایل ها و خواندن و چانک کردن و امبدینگ درست
# مانع:مشکل سیستم قدیمی و نصب فایاز و اجرا نشدن
# فردا:ادامه با سرچ نامپای بعدا با سیستم قوی تقویت فعلا اجرا کامل با همین سیستم
#
# ارشد :
# فقط درست کردن چت جدید و گفتم پرامپت ها
# مانع خود هوش مصنوعی
# شروع تست ها از چهار
#
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# شنبه ۲۹ آذر
# قسمت کد :
# ده برای برابر طول اس و صفر شده و درست کردن لیست ال و اس درست شد.
# مانع :مشکل خواندن نقطه
# فردا : خواندن نقطه و مرتب سازی کد
#
# فینال راگ:
# الحمدلله انجام شدو تست مثبت انگلیسی
# مانع نبود
# فردا ان شاالله : تست فارسی و بعد هم حجیم
#
#
#
# ارشد:
# وقت نشد.
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# دوشنبه ۱ دی ماه
# کد :
# قسمت درست گرفتن کامل انجام شد
# مانع :قسمت چند تا خوردن
# الگوریتم هوشمص برای جلو رفتن با تعداد تقریبا درست بعدا اجرایی شود.
#
#
# فاینال راگ:
# تست فارسی اوکی تست حجیم کامل نشد
# مانع: ضعف سی پی یو
# بااینکه خانه پنج ساعت تست ۵۰۰ مگ گرفتم نشد باید بروم روی تست ۱۰۰ مگ
#
#
# ارشد:
# انجام نشد.
#
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# سه شنبه ۲ دی ماه
#
# کد :
# قسمت پیمایش و مچ
# مانع : مچ فور برای طول های هر دو
# مچ کردن با پاپ کردن عناصر ستاره دار
#
# راگ:
# تست در خانه گرفته شد پنج ساعت جواب نداد
# مانع سی پی یو
# دوباره تست در خانه روی صد
#
#
# ارشد:
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# شنبه ۶ دی ماه ۱۴۰۴
#
#
# کد :
# سوال دهم با کمک حل شد چون اولا سخت بود دوم راه حل من جواب نمیداد یا خیلی زمان میبرد
# سوال یازدهم و دوازدهم و سیزدهم هم تموم شد
# مشکلی نبود
# مانع : همان گیر افتادن وقتی کامل اموزش ندیدی
# فردا : برنامه اموزش هم اورده شود.
#
# راگ:
# مقایسه راگ با فاین تون
# مانع: نبودهمان راگ تا انتها برو
# بعد ها اول فاین تون و بعد راگ
# و خانه تست شود صد مگ
# ارشد:
#
#
# اموزش:
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# یکشنبه ۷ دی ۱۴۰۴
#
# کد:
# به دلیل مشکلات الگوریتمی و بلد نبودن و پراکندگی سوال ها رفتم سراغ لیت کد۷۵ که با ترتیب مساله ها را میاورد
# مانع: بلد نبودن الگوریم
# فردا : ادامه حل لیت کد که سوال یک حل شد و پرامپت الگوریتم هم ست شد.
#
#
# راگ:
#
#
#
# ارشد:
#
#
#
# اموزش:
#
#
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# دوشنبه ۸ دی ۱۴۰۴
# کد:
# سوال دوم حل شد در ۷۵ لیت کد هستیم
# بی مانع
# فردا بعدی ها حداقل یک ساعت
#
#
# راگ:
# تست دو مگ و پنج مگ گرفته شدو و حدودا ۴۰ دیقه شد
# مانع: عدمتوانای سی پی یو
# حرکت :مرتب سازی کدها برای پوش نهایی و داکر
#
#
# ارشد:
# اموزش:
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# سه شنبه ۹ دی ماه ۱۴۰۴
# کد :
# سوالات سه وچهار حل شد در لیست هاهستیم
# بی مانع
# حرکت :ادامه
#
#
# راگ :
# فایل ها مرتب داکر نصب
# مانع : مک
# حرکت:اجرا روی سرور
#
# ارشد:
# اموزش:
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# چهارشنبه ۱۰ دی ماه ۱۴۰۴
# کد:
# سوالات شش وهفت حل شد.
# بدون مانع
# بعدی ها
#
#
# راگ:
# سرور خریداری و با
# ssh
# وصل به vscode
# و اجرا
# مانع: همان کندی در اینجا با رم و سی پی یو ۱۶ برقرار
# حرکت: ایمیج داکر برای تست در جی پی یو بهتر
#
#
#
# ارشد:
# اموزش:
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# پنجشنبه ۱۱ دی ۱۴۰۴
#
# کد:وقت نشد عملا
# راگ:تست سرور و تست داکر
# مانع : سی پی یو کند و بدون جی پی یو نمیشود
# حرکت:
#
# ارشد :
# اموزش:
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# دوشنبه ۱۵ دی ماه ۱۴۰۴
#
# کد:
#
#
# یادگیری ماشین:
# در کولب تست ۲ و۵ و ۱۰۰ و۵۰۰ را گرفتم و اوکی بود تست ۱۰۰ و ۵۰۰ با چانک پایین بود.
# مانع : تست چانک بالا ۶۶هزار تا در ۱۰۰ مگ بخاطر قعطی زیاد ناموفق
# حرکت: راه خروجی با جی پی یو و تست مدل راگ
#
# ارشد:
# اموزش:
#
#
# </div>
